# %%
# Let's now cluster our self-trained Wikipedia discussions model
from gensim.models import Word2Vec

model = Word2Vec.load("data/wue15_word2vec.model")
model = model.wv

# %%
# Get the words and their vectors
words = model.index_to_key
word_vectors = model[words]
print("Number of vectors to be clustered:", len(word_vectors))
# Out:
# Number of vectors to be clustered: 115621

# %%
from sklearn import cluster
# We will use the KMeans clustering algorithm
# We need to choose a number of clusters (k)
# We will not use too many clusters so it goes fast
k = 500

# An alternative would be to take a certain percentage, e.g. 2.4 % of the number of types
# k = int(len(word_vectors) * 0.024)

print("Number of clusters:", k)
kmeans = cluster.KMeans(n_clusters=k)
kmeans.fit(word_vectors)
# Out:
# Number of clusters: 500
# KMeans(n_clusters=500)

# %%
import pickle
# Save the model
with open("data/kmeans_wue15_word2vec.pkl", "wb") as f:
    pickle.dump(kmeans, f)

# %%
import pickle
# Read the model
with open("data/kmeans_wue15_word2vec.pkl", "rb") as f:
    kmeans = pickle.load(f)

# %%
# The labels are the cluster IDs for each word
kmeans.labels_
# Out:
# array([189, 189, 244, ..., 215, 215, 369], dtype=int32)

# %%
# Let's create a dictionary to map words to their cluster IDs

word_cluster = dict(zip(words, kmeans.labels_))
print(word_cluster)

cluster_words = {}
for word, cluster in word_cluster.items():
    if cluster not in cluster_words:
        cluster_words[cluster] = []
    cluster_words[cluster].append(word)
# Out:
# {',': 189, '.': 189, 'the': 244, 'to': 189, 'you': 170, '(': 457, ')': 457, 'and': 189, 'of': 189, 'a': 244, 'for': 189, ':': 470, 'that': 189, 'I': 170, 'UTC': 472, 'is': 213, 'on': 473, '"': 13, 'in': 189, 'it': 495, 'page': 152, 'Wikipedia': 164, 'be': 171, 'your': 196, 'have': 188, 'not': 189, 'this': 244, 'or': 189, 'article': 486, 'If': 321, 'deletion': 463, 'are': 88, '!': 417, 'as': 189, 'with': 189, 'at': 489, 'will': 22, 'can': 22, 'Image': 53, 'use': 313, 'talk': 164, 'but': 189, '|': 359, 'an': 244, 'by': 233, 'The': 495, 'any': 498, 'may': 22, 'if': 321, 'was': 88, 'image': 264, 'from': 189, '2007': 72, 'please': 347, 'Please': 124, 'do': 69, 'my': 196, '2008': 72, 'speedy': 41, 'pages': 152, 'been': 376, 'copyright': 139, 'about': 189, 'deleted': 419, 'has': 188, 'see': 69, 'would': 203, '/': 96, '?': 189, 'like': 287, 'more': 130, 'articles': 432, '--': 472, ';': 189, 'You': 426, '-': 323, 'Thanks': 458, 'me': 414, 'edit': 340, 'other': 280, 'tag': 110, 'welcome': 351, 'Thank': 255, '2006': 72, 'here': 149, 'information': 451, 'one': 179, 'questions': 129, 'some': 322, 'help': 69, '=': 276, 'name': 479, 'all': 280, 'just': 6, 'which': 495, "don't": 24, 'ask': 362, 'so': 189, 'think': 163, 'there': 7, "'": 179, 'criteria': 57, 'what': 289, 'add': 381, 'images': 401, '2009': 72, 'out': 477, 'media': 461, 'then': 189, 'note': 175, 'This': 495, 'should': 22, '&gt;': 387, 'our': 450, 'hope': 163, 'guidelines': 488, 'editing': 10, 'them': 414, 'used': 389, 'they': 426, 'find': 456, 'using': 383, 'policy': 218, '&lt;': 267, 'fair': 155, 'place': 442, 'How': 16, 'under': 195, 'being': 6, 'remove': 443, 'why': 290, '}': 95, 'March': 12, 'link': 418, '̈': 61, 'check': 371, 'know': 163, 'need': 287, 'we': 170, 'also': 6, 'list': 375, 'Welcome': 16, 'May': 12, "I'm": 17, 'time': 80, 'links': 222, 'up': 477, 'January': 12, 'source': 305, "Wikipedia's": 450, 'when': 136, '21': 302, 'content': 451, '20': 302, 'want': 287, 'only': 6, 'April': 12, 'edits': 480, 'February': 12, 'because': 136, 'June': 12, 'make': 129, 'Hello': 482, '22': 302, 'adding': 10, 'uploaded': 492, 'notice': 239, 'discussion': 463, 'yourself': 245, 'July': 12, '23': 302, 'new': 7, 'no': 244, 'question': 221, 'October': 12, 'might': 22, 'December': 12, 'get': 27, '—': 0, 'August': 12, 'top': 219, 'description': 122, 'who': 308, 'good': 404, 'November': 12, 'user': 464, '...': 417, 'contributions': 480, 'September': 12, 'very': 6, 'free': 347, 'non-free': 269, 'does': 257, 'how': 278, 'It': 495, 'could': 22, 'Your': 196, 'created': 266, 'tags': 296, 'For': 284, 'such': 7, 'write': 69, 'without': 189, 'However': 484, 'after': 15, 'message': 315, 'great': 404, 'WP': 164, 'sign': 420, 'read': 69, 'am': 17, 'where': 136, 'File': 53, 'its': 51, 'look': 286, 'now': 6, 'people': 274, '2': 47, 'font': 325, 'automatically': 132, 'work': 102, ':C': 470, 'did': 24, 'before': 15, 'added': 319, 'tildes': 35, 'their': 150, 'he': 308, 'first': 15, 'were': 88, 'way': 486, 'well': 404, 'four': 384, 'uploading': 272, 'these': 280, 'date': 475, 'it.': 414, 'go': 406, 'Here': 141, '1': 47, 'tagged': 304, 'policies': 58, 'following': 23, 'rationale': 131, 'removed': 377, 'account': 464, 'section': 105, 'leave': 459, "I've": 399, 'his': 150, 'notable': 126, 'feel': 107, 'made': 405, 'had': 188, 'template': 168, "it's": 213, 'stay': 69, 'than': 189, 'again': 417, 'days': 275, 'someone': 414, 'Again': 437, 'decide': 120, 'enjoy': 344, 'status': 352, 'too': 6, 'take': 46, 'once': 121, 'User': 164, '&amp;': 37, '3': 47, 'five': 81, 'reverted': 341, 'A': 66, '4': 47, 'still': 6, 'Wikipedian': 225, 'pillars': 83, 'Style': 116, 'problem': 202, 'Hi': 482, 'sources': 305, 'In': 25, 'Manual': 116, 'back': 477, 'few': 328, 'subject': 486, 'contest': 128, 'placed': 143, 'request': 463, '5': 47, 'much': 404, 'explaining': 200, 'below': 93, 'sure': 73, 'To': 25, 'comment': 254, 'currently': 6, 'position': 349, 'same': 244, 'Tutorial': 116, 'sandbox': 194, 'those': 280, 'encyclopedia': 486, 'i ...

# %%
import numpy as np

cluster_centroid = {}
for cluster, words in cluster_words.items():
    vectors = [model[word] for word in words]
    cluster_centroid[cluster] = np.mean(vectors, axis=0)

# %%
from scipy.spatial import distance
import pandas as pd

# Create DataFrame for cluster assignment and similarity
df = pd.DataFrame(word_cluster.items(), columns=["word", "cluster"])
df["sim"] = [
    1 - distance.cosine(model[word], cluster_centroid[cluster])
    for word, cluster in word_cluster.items()
]
df = df.sort_values(by=["cluster", "sim"], ascending=[True, False])

# %%
df
# Out:
#              word  cluster       sim
# 20821         5pm        0  0.853182
# 28842  Eventbrite        0  0.795898
# 18383        11am        0  0.794542
# 44720     2pm–5pm        0  0.793528
# 53748     Guapo's        0  0.789034
# ...           ...      ...       ...
# 731            An      496  1.000000
# 1043        wikis      497  0.949709
# 3736   Wikipedias      497  0.881928
# 46            any      498  1.000000
# 759        upload      499  1.000000
#
# [115621 rows x 3 columns]

# %%
word_cluster["attack"]
# Out:
# 60

# %%
word = "post"
cluster = word_cluster[word]
cluster_words[cluster]
# Out:
# ['answer', 'post', 'reply', 'response', 'respond']

# %%
# Create top-3 word labels for each cluster
cluster_label = {cluster: "|".join(words[:3]) for cluster, words in cluster_words.items()}

# %%
cluster_label
# Out:
# {189: ',|.|to',
#  244: 'the|a|this',
#  170: 'you|I|we',
#  457: '(|)|Disambiguation',
#  470: ':|:C|:P',
#  472: 'UTC|--',
#  213: "is|it's|It's",
#  473: 'on',
#  13: '"|original|fact',
#  495: 'it|The|which',
#  152: 'page|pages',
#  164: 'Wikipedia|talk|WP',
#  171: 'be|show|include',
#  196: 'your|my|Your',
#  188: 'have|has|had',
#  486: 'article|way|subject',
#  321: 'If|if',
#  463: 'deletion|discussion|request',
#  88: 'are|was|were',
#  417: '!|...|again',
#  489: 'at|At',
#  22: 'will|can|may',
#  53: 'Image|File',
#  313: 'use',
#  359: '|',
#  233: 'by',
#  498: 'any',
#  264: 'image',
#  72: '2007|2008|2006',
#  347: 'please|free|going',
#  124: 'Please',
#  69: 'do|see|help',
#  41: 'speedy',
#  376: 'been|happened|appeared',
#  139: 'copyright|external|web',
#  419: 'deleted',
#  203: "would|I'd|you'd",
#  96: '/|Archive|Users',
#  287: 'like|need|want',
#  130: 'more|better|rather',
#  432: 'articles',
#  426: 'You|they|We',
#  323: '-|No|Unfortunately',
#  458: 'Thanks|thanks',
#  414: 'me|them|it.',
#  340: 'edit|reason|addition',
#  280: 'other|all|these',
#  110: 'tag',
#  351: 'welcome',
#  255: 'Thank|thank',
#  149: 'here|bold|seriously',
#  451: 'information|content|material',
#  179: "one|'|part",
#  129: 'questions|make|put',
#  322: 'some|lot|lots',
#  276: '=',
#  479: 'name|username',
#  6: 'just|being|also',
#  24: "don't|did|doesn't",
#  362: 'ask',
#  163: 'think|hope|know',
#  7: 'there|new|such',
#  57: 'criteria',
#  289: 'what|something|anything',
#  381: 'add',
#  401: 'images|files',
#  477: 'out|up|back',
#  461: 'media',
#  175: 'note',
#  387: '&gt;',
#  450: "our|Wikipedia's",
#  488: 'guidelines',
#  10: 'editing|adding|making',
#  389: 'used',
#  456: 'find|reach|figure',
#  383: 'using',
#  218: 'policy|notability|verifiability',
#  267: '&lt;|background|#if',
#  155: 'fair',
#  442: 'place',
#  16: 'How|Welcome|Help',
#  195: 'under',
#  443: 'remove',
#  290: 'why',
#  95: '}|[|{',
#  12: 'March|May|January',
#  418: 'link',
#  61: '̈|\u200c|regex',
#  371: 'check',
#  375: 'list',
#  17: "I'm|am|you're",
#  80: 'time|listed|least',
#  222: 'links|templates|names',
#  305: 'source|sources|references',
#  136: 'when|because|where',
#  302: '21|20|22',
#  480: 'edits|contributions|changes',
#  482: 'Hello|Hi|Sorry',
#  492: 'uploaded',
#  239: 'notice',
#  245: 'yourself',
#  221: 'question',
#  27: 'get|come|pass',
#  0: '—|–|Doing',
#  219: 'top',
#  122: 'description',
#  308: 'who|he|He',
#  404: 'good|great|well',
#  464: 'user|account|log',
#  269: 'non-free',
#  257: 'does',
#  278: 'how',
#  266: 'created|blank|moved',
#  296: 'tags',
#  284: 'For',
#  484: 'However|Lastly',
#  15: 'after|before|first',
#  315: 'message',
#  420: 'sign',
#  51: 'its|wikipedia|community',
#  286: 'look',
#  274: 'people|us|users',
#  47: '2|1|3',
#  325: 'font|sup|timestamp',
#  132: 'automatically',
#  102: 'work|cooperation|efforts',
#  319: 'added|changed|updated',
#  35: 'tildes',
#  150: 'their|his|her',
#  384: 'four',
#  272: 'uploading|See|Re',
#  475: 'date',
#  406: 'go|got|came',
#  141: 'Here',
#  304: 'tagged',
#  58: 'policies|sites|works',
#  23: 'following|above|author',
#  131: 'rationale',
#  377: 'removed',
#  105: 'section|history|entry',
#  459: 'leave',
#  399: "I've|you've",
#  126: 'notable|included|considered',
#  107: 'feel|consider|say',
#  405: 'made|done|found',
#  168: 'template|text|category',
#  275: 'days|years|times',
#  437: 'Again',
#  120: 'decide',
#  344: 'enjoy',
#  352: 'status',
#  46: 'take|address|discuss',
#  121: 'once|doing|sorry',
#  37: '&amp;|amp|testing',
#  81: 'five|group|number',
#  341: 'reverted',
#  66: 'A|Speedy|Proposed',
#  225: 'Wikipedian',
#  83: 'pillars',
#  116: 'Style|Manual|Tutorial',
#  202: 'problem|issue|issues',
#  25: 'In|To|As',
#  328: 'few|couple',
#  128: 'contest',
#  143: 'placed',
#  200: 'explaining',
#  93: 'below',
#  73: 'sure|aware|happy',
#  254: 'comment|comments|warning',
#  349: 'position',
#  194: 'sandbox|dropdown|newsletter',
#  28: 'answer|post|reply',
#  38: 'automated',
#  298: 'license|CC-BY-SA|reuse',
#  204: ']]',
#  435: 'WikiProject|project|Article',
#  197: 'file',
#  29: 'vandalism|blocked|block',
#  258: 'meets',
#  343: 'error',
#  99: 'hesitate',
#  172: 'existing',
#  113: 'color|background-color|font-family',
#  71: 'own|evidence|reasons',
#  173: '2010|2011|2013',
#  455: 'bot',
#  439: 'edited',
#  416: 'helpful',
#  174: '%|100|half',
#  70: 'Wikimedia',
#  309: 'produce',
#  78: 'db',
#  413: '[[|button|Signature',
#  77: 'criterion',
#  226: 'stop|refrain',
#  300: 'indicate',
#  14: 'Questions',
#  106: ':3',
#  261: 'proposed',
#  252: "I'll|you'll|Would",
#  209: "article's|page's",
#  446: 'let|asking|personally',
#  238: 'delay',
#  410: 'contact',
#  127: 'provided',
#  471: 'contributing',
#  142: 'described',
#  87: 'verify',
#  262: 'person|member|chance',
#  307: 'seven',
#  185: 'insert',
#  52: 'align',
#  453: 'appropriate|important|correct',
#  350: 'Articles',
#  353: 'Note',
#  491: 'whether|either|whatever',
#  119: 'coupled',
#  227: 'messages',
#  409: 'tagging',
#  214: 'accepted',
#  94: 'useful',
#  193: 'Special',
#  138: 'shortly',
#  367: 'accounts',
#  246: 'nominated',
#  433: 'change|delete|revert',
#  481: 'give|provide',
#  490: 'style',
#  206: 'seems|appears|seemed',
#  89: "image's",
#  310: 'box|line|space',
#  169: 'Media',
#  425: 's|*|i.',
#  134: 'clicking',
#  454: 'future',
#  63: 'render',
#  97: 'interested',
#  316: 'conformance',
#  374: 'said|noticed|thought',
#  123: 'Fair|Non-free',
#  236: 'week',
#  372: 'summary|war|warring',
#  201: 'located',
#  395: 'left|posted|asked',
#  335: 'Feel',
#  427: 'editor|admin|administrator',
#  363: 'speedily',
#  158: 'logged',
#  251: 'Information.svg',
#  462: 'biographies',
#  242: 'contribute',
#  256: 'All|These|Some',
#  338: 'site|company|band',
#  98: 'called|open|active',
#  441: 'claim',
#  178: 'day|year|today',
#  467: 'continue',
#  159: 'creator',
#  408: 'seem|appear',
#  403: 'selecting',
#  388: '•|·',
#  235: 'permission',
#  117: 'acceptable',
#  217: 'not.',
#  86: 'newcomers',
#  148: 'previously',
#  75: 'ontributions',
#  237: 'removing',
#  146: 'Orphaned',
#  339: "they're",
#  259: 'prevent',
#  348: 'soon',
#  181: 'receiving',
#  355: 'type|working|based',
#  460: 'checking',
#  440: 'copyrighted|advertising|inappropriate',
#  271: 'search|title',
#  452: 'email|e-mail',
#  68: "List|maintainer's|remaining",
#  281: 'conflict',
#  478: 'meaning',
#  20: 'required|unsigned|typing',
#  469: 'Or|Alternatively',
#  60: 'further|action|permissions',
#  109: 'explanation',
#  224: 'Good|Featured|featured',
#  49: 'specified',
#  205: 'appreciated',
#  92: 'release',
#  112: 'click',
#  5: 'else|available|domain',
#  207: 'specifies',
#  144: 'emailed',
#  111: 'English|language|American',
#  330: 'span|Copyright|Disputed',
#  263: 'per|Read|WMD',
#  291: 'identified',
#  380: 'confirm',
#  180: 'experiment',
#  317: 'GFDL|License|Free',
#  165: 'picture|pictures|photo',
#  232: 'related|according|including',
#  42: 'current|team|potential',
#  346: 'improve|expand',
#  234: 'constructive',
#  434: 'inclusion',
#  412: 'agree|disagree',
#  487: '#39',
#  294: "isn't|makes|took",
#  190: 'orphaned',
#  282: 'needs',
#  167: 'start|play|present',
#  79: 'tools|wiki|software',
#  43: 'replacement',
#  187: 'types',
#  248: 'unlicensed',
#  76: 'etc.|music|etc',
#  382: 'companies|bands|musicians',
#  400: 'involved|comply|experimenting',
#  160: 'indicating',
#  429: 'experienced',
#  153: 'requesting',
#  33: 'main|Edit|redirect',
#  240: 'nothing',
#  496: 'An',
#  241: 'Take',
#  32: 'specifying',
#  223: 'assert',
#  361: 'apps|Nuvola|blue.svg',
#  59: 'imdb.com|muppitshut|ਾ',
#  103: "subject's",
#  499: 'upload',
#  34: 'Images',
#  273: 'A7|Using|Under',
#  396: 'renamed',
#  183: 'de|en|e',
#  364: 'Deletion',
#  393: 'creation',
#  292: 'Foundation|re-use|permitting',
#  428: 'notification',
#  85: 'Wiki|key|design',
#  231: 'holder',
#  415: 'raised',
#  320: 'projects',
#  391: 'qualify',
#  423: 'disambiguation',
#  208: 'e.|licensing|Use',
#  192: 'center|DC|Meetup',
#  247: 'hours|minutes|hour',
#  198: 'says|Is|states',
#  118: 'Community|History|Archives',
#  336: 'Issue',
#  312: 'violation',
#  140: 'worked|sent|run',
#  407: 'Did',
#  151: 'mistake|life|friend',
#  40: 'set|coming|Keep',
#  485: 'meet|violate',
#  277: 'colspan',
#  230: 'queries',
#  386: 'qualifies',
#  84: 'determined',
#  483: 'result',
#  54: 'conform',
#  11: 'Hi.|Page|More',
#  379: 'stuck',
#  19: '48|50|00',
#  3: 'Best|opt-out|Contribute',
#  211: 'introduction',
#  279: 'altered',
#  161: 'tips|advice|opinions',
#  327: 'video|audio',
#  147: 'compliance',
#  430: 'drop',
#  114: 'userfy',
#  253: 'delivered',
#  125: 'legally',
#  411: 'S.|John|P.',
#  385: 'FAQ',
#  100: 'invalid',
#  299: 'vandalize',
#  191: 'unconstructive',
#  31: 'lacking|official|independent',
#  184: 'World|Championship|WWE',
#  8: 'nonsense|specifically|mine',
#  366: 'specify',
#  283: 'NOTE',
#  2: 'About|View|Work',
#  447: 'Notability',
#  497: 'wikis|Wikipedias',
#  45: 'pointing|break|straight',
#  154: 'receive',
#  468: 'owner',
#  229: 'assistance',
#  398: 'publication',
#  390: 'glad|wondering|hoping',
#  270: 'tests',
#  288: 'features',
#  402: 'pick',
#  449: 'require',
#  297: 'basic',
#  438: 'participate',
#  177: 'DYK|suggestion|submission',
#  210: 'school|live|man',
#  39: 'untagged|Unsourced',
#  421: 'suitable',
#  260: 'uniform|Go|match',
#  216: 'India|United|Church',
#  394: 'freely|licensed|replaceable',
#  199: 'standards|requirements',
#  133: 'credited',
#  306: 're-users',
#  228: 'Yours|regards|Sincerely',
#  474: 'encyclopedic',
#  345: "apologies|creator's",
#  26: 'University|School|South',
#  135: 'unsubscribe',
#  365: 'Sandbox',
#  166: 'Jack|Alex|Andrew',
#  182: 'reserved|enwiki',
#  295: 'developer',
#  249: 'Editing|needing|khelpcenter.png',
#  397: 'linking',
#  466: 'subjects',
#  431: 'flexible',
#  243: '”|“|Christian',
#  476: 'pump|village',
#  342: 'on-going',
#  56: 'attach|MergeAccount',
#  333: 'borrowed',
#  318: 'clashes',
#  331: 'replace',
#  332: 'Volume',
#  104: 'side-effects',
#  64: 'Keegan|Liaison|Renamed',
#  369: 'Peterzell|PW|maki',
#  268: 'constitutes',
#  186: 'NOT|THE|YOU',
#  311: 'matches',
#  337: 'invited',
#  493: 'delivery',
#  354: 'satisfy',
#  334: 'law|violations|infringement',
#  176: 'informing',
#  55: 'entire|Unreferenced|improvement',
#  74: 'Requests|Files|Templates',
#  48: 'Dull|Dan|Guy',
#  314: 'Naming|unfree|Removing',
#  108: "file's",
#  101: 'seeing|except|starting',
#  265: 'Dab|solver',
#  360: 'unintended',
#  444: 'perform',
#  50: 'dot|wikimedia|org',
#  368: 'accordance',
#  91: '्|ा|ि',
#  324: 'steps',
#  436: 'SuggestBot',
#  358: 'similarity',
#  285: 'desk|Village|Desk',
#  157: 'Our|drive|backlog',
#  1: "item|nofollow|SuggestBot's",
#  392: 're-adding',
#  465: 'robot|notices|Greetings',
#  494: 'belongs',
#  424: 'opt',
#  67: 'rankings|Editors|corporations',
#  445: 'PM',
#  62: 'ClueBot|default|caused',
#  44: 'Apr|Jun|Mar',
#  370: 'rewriting',
#  301: 'select',
#  329: 'affix',
#  356: 'Simplified|Ruleset',
#  156: 'failed|helped|joined',
#  378: 'satisfies',
#  373: 'undeletion',
#  4: 'Make|spot|Consider',
#  9: 'Try|meantime|past.',
#  82: "website's|restatement",
#  422: 'coordinators',
#  145: 'choosing',
#  326: 'rewritten|fundamentally',
#  21: 'addresses|awards|hits',
#  448: 'Contents|Revert|Simple',
#  30: 'voice|challenge|self',
#  65: 'gray|daily|net',
#  357: 'signified',
#  215: 'whenever|Simply|accordingly',
#  303: 'substantially|Recently|hang-on',
#  162: 'signify',
#  220: 'alerting',
#  250: 'La|die|em',
#  115: 'Bold|，|caretaker',
#  18: 'Blocked|Jimbo|actively',
#  137: 'package|promptly|Civility',
#  212: 'Being|newly|merger',
#  293: 'Gold|Address|MS',
#  90: 'IMHO|Certainly|presently',
#  36: 'youtube|alongside|merges'}

# %%
def sort_dict(dic, reverse=True):
    """
    Sort a dictionary by its values.

    Args:
        dic (Dict): Dictionary to sort.
        reverse (bool): Whether to sort in descending order.

    Returns:
        Dict: Sorted dictionary.
    """
    return dict(sorted(dic.items(), key=lambda item: item[1], reverse=reverse))


def get_similar_clusters(
    word_or_vec, topn=10, least=False
):
    """
    Get the most or least similar clusters for a given word or vector.

    Args:
        word_or_vec (Union[str, np.ndarray]): Word or vector to compare.
        topn (int): Number of clusters to return.
        least (bool): Whether to return least similar clusters.

    Returns:
        List[Tuple[int, float]]: List of cluster indices and similarity scores.
    """
    if isinstance(word_or_vec, str):
        vector = model[word_or_vec]
    elif isinstance(word_or_vec, np.ndarray):
        vector = word_or_vec
    else:
        raise ValueError("Input must be a string (word) or a NumPy array (vector).")

    # Compute similarities to all cluster centroids
    cluster_similarities = {
        cluster: 1 - distance.cosine(vector, centroid)
        for cluster, centroid in cluster_centroid.items()
    }
    sorted_clusters = sort_dict(cluster_similarities, reverse=not least)
    return list(sorted_clusters.items())[:topn]

def print_similar_clusters(
    word_or_vec, topn=10, least=False
):
    """
    Print the most or least similar clusters for a given word or vector.

    Args:
        word_or_vec (Union[str, np.ndarray]): Word or vector to compare.
        topn (int): Number of clusters to print.
        least (bool): Whether to print least similar clusters.
    """
    clusters = get_similar_clusters(word_or_vec, topn=topn, least=least)
    for cluster, similarity in clusters:
        if cluster in cluster_label:
            print(f"Cluster {cluster}: {cluster_label[cluster]} (Similarity: {similarity:.3f})")

# %%
print_similar_clusters("write", topn=10)
# Out:
# Cluster 69: do|see|help (Similarity: 0.623)
# Cluster 129: questions|make|put (Similarity: 0.602)
# Cluster 167: start|play|present (Similarity: 0.537)
# Cluster 456: find|reach|figure (Similarity: 0.535)
# Cluster 433: change|delete|revert (Similarity: 0.495)
# Cluster 381: add (Similarity: 0.474)
# Cluster 4: Make|spot|Consider (Similarity: 0.470)
# Cluster 46: take|address|discuss (Similarity: 0.468)
# Cluster 481: give|provide (Similarity: 0.463)
# Cluster 27: get|come|pass (Similarity: 0.458)
